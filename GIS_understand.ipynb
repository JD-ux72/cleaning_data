# %%
import pandas as pd

spatial_hierarchy  ={
    "Administrative level" :["Level 0 (country)", "Level 1 (Province/state)", "Level 2 (District)", "Level 3 (Municipality)", "Level 4 (Hyper-local unit)"],
    "GIS" : ["ADM0","ADM1", "ADM2", "ADM3", "ADM4"],
    "Example" : ["South Africa", "Gauteng province", "Sedibeng District muncipality", "Lesedi Local Municipality", "Wards"]

}

df = pd.DataFrame(spatial_hierarchy)

df
# Out:
#          Administrative level   GIS                        Example
# 0           Level 0 (country)  ADM0                   South Africa
# 1    Level 1 (Province/state)  ADM1               Gauteng province
# 2          Level 2 (District)  ADM2  Sedibeng District muncipality
# 3      Level 3 (Municipality)  ADM3      Lesedi Local Municipality
# 4  Level 4 (Hyper-local unit)  ADM4                          Wards
